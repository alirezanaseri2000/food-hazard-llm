# %%
import pandas as pd
import subprocess, re, time
from pathlib import Path
from sklearn.metrics import classification_report, accuracy_score, f1_score

MODEL = "llama3.1:8b"
INPUT_CSV = "incidents_test.csv"  # <-- test

OUT_DIR = Path("results")
OUT_DIR.mkdir(exist_ok=True)

OUT_CSV = OUT_DIR / "zero_shot_test_all_strict.csv"  # <-- test output
SAVE_EVERY = 20

HAZ_LIST = [
    "allergens", "biological", "chemical", "food additives and flavourings",
    "foreign bodies", "fraud", "migration", "organoleptic aspects",
    "other hazard", "packaging defect"
]

PROD_LIST = [
    "alcoholic beverages", "cereals and bakery products",
    "cocoa and cocoa preparations, coffee and tea", "confectionery",
    "dietetic foods, food supplements, fortified foods", "fats and oils",
    "feed materials", "food additives and flavourings", "food contact materials",
    "fruits and vegetables", "herbs and spices", "honey and royal jelly",
    "ices and desserts", "meat, egg and dairy products", "non-alcoholic beverages",
    "nuts, nut products and seeds", "other food product / mixed", "pet feed",
    "prepared dishes and snacks", "seafood",
    "soups, broths, sauces and condiments", "sugars and syrups"
]

PROMPT_TEMPLATE = """You are a food safety incident classifier.

Choose labels ONLY from the allowed lists.
Do NOT invent new labels. If unsure, choose the closest match based on definitions.

Hazard-category definitions (use these):
- allergens: undeclared allergens or allergen contamination.
- biological: pathogenic microorganisms (bacteria/viruses/parasites), spoilage microbes, mycotoxins of biological origin.
- chemical: chemicals, toxins (non-biological), residues, heavy metals, cleaning agents.
- food additives and flavourings: issues specifically about additives/flavourings (unauthorized, excessive, wrong additive).
- foreign bodies: physical objects (plastic, glass, metal, stones).
- fraud: intentional deception (mislabeling, substitution, counterfeit, origin fraud).
- migration: substances migrating from packaging/materials into food.
- organoleptic aspects: abnormal smell/taste/texture/appearance without a clear contaminant.
- other hazard: hazards that do not fit above categories.
- packaging defect: packaging integrity/closure/seal defects causing risk.

Product-category guidance:
Pick the category that best matches the recalled product itself (not the ingredient).
If the product is a meal/ready-to-eat item, prefer "prepared dishes and snacks".
If it is clearly a raw/processed meat/egg/dairy item, prefer "meat, egg and dairy products".

Before choosing labels, internally identify:
- the hazard evidence phrase (e.g., "Listeria", "plastic fragment", "undeclared milk")
- the recalled product phrase (e.g., "ham, sliced", "cookies", "baby formula")
Use those internal findings to select the closest allowed labels.

Output ONLY two lines, no extra text.
Line1 must be: hazard-category: <one of: {haz_opts}>
Line2 must be: product-category: <one of: {prod_opts}>

Report:
Title: {title}
Text: {text}
""".strip()


def run_ollama(prompt: str) -> str:
    res = subprocess.run(
        ["ollama", "run", MODEL, prompt],
        capture_output=True,
        text=True,
        encoding="utf-8",
        errors="replace"
    )
    if res.returncode != 0:
        raise RuntimeError(res.stderr)
    return res.stdout.strip()


def parse_two_lines(out: str):
    haz = None
    prod = None

    m1 = re.search(r"hazard-category\s*:\s*(.+)", out, flags=re.IGNORECASE)
    m2 = re.search(r"product-category\s*:\s*(.+)", out, flags=re.IGNORECASE)

    if m1:
        haz = m1.group(1).strip()
    if m2:
        prod = m2.group(1).strip()

    def norm(x):
        if x is None:
            return None
        x = x.strip().strip('"').strip("'").strip()
        x = re.sub(r"\s+", " ", x)
        x = x.rstrip(" .,:;")
        return x

    haz = norm(haz)
    prod = norm(prod)

    haz_in_list = (haz in HAZ_LIST) if haz else False
    prod_in_list = (prod in PROD_LIST) if prod else False

    if not haz_in_list:
        haz = None
    if not prod_in_list:
        prod = None

    parse_ok = (haz is not None) and (prod is not None)
    return haz, prod, parse_ok, haz_in_list, prod_in_list


def compute_metrics_if_labels_exist(df_res: pd.DataFrame):
    # if test has no ground-truth, skip metrics cleanly
    if ("haz_true" not in df_res.columns) or ("prod_true" not in df_res.columns):
        print("\nNo ground-truth columns found. Skipping metrics.")
        return
    if df_res["haz_true"].isna().all() or df_res["prod_true"].isna().all():
        print("\nGround-truth appears empty. Skipping metrics.")
        return

    df_ok = df_res[df_res["parse_ok"] == True].copy()
    if len(df_ok) == 0:
        print("\nNo parse_ok samples. Cannot compute metrics.")
        return

    # Hazard
    y_true = df_ok["haz_true"].astype(str)
    y_pred = df_ok["haz_pred"].astype(str)
    print("\n=== Hazard-category Metrics (on parse_ok samples: {}/{}) ===".format(len(df_ok), len(df_res)))
    print("Accuracy:", accuracy_score(y_true, y_pred))
    print("Macro-F1:", f1_score(y_true, y_pred, average="macro", zero_division=0))
    print("Micro-F1:", f1_score(y_true, y_pred, average="micro", zero_division=0))
    print("Weighted-F1:", f1_score(y_true, y_pred, average="weighted", zero_division=0))
    print("\nClassification Report:\n")
    print(classification_report(y_true, y_pred, zero_division=0))

    # Product
    y_true = df_ok["prod_true"].astype(str)
    y_pred = df_ok["prod_pred"].astype(str)
    print("\n=== Product-category Metrics (on parse_ok samples: {}/{}) ===".format(len(df_ok), len(df_res)))
    print("Accuracy:", accuracy_score(y_true, y_pred))
    print("Macro-F1:", f1_score(y_true, y_pred, average="macro", zero_division=0))
    print("Micro-F1:", f1_score(y_true, y_pred, average="micro", zero_division=0))
    print("Weighted-F1:", f1_score(y_true, y_pred, average="weighted", zero_division=0))
    print("\nClassification Report:\n")
    print(classification_report(y_true, y_pred, zero_division=0))


def main():
    df = pd.read_csv(INPUT_CSV)
    n = len(df)
    print(f"Loaded {n} rows from {INPUT_CSV}")

    # resume support
    done = {}
    if OUT_CSV.exists():
        prev = pd.read_csv(OUT_CSV)
        for _, r in prev.iterrows():
            done[int(r["idx"])] = r.to_dict()
        print(f"Resuming: found {len(done)} already processed rows in {OUT_CSV}")

    haz_opts = "; ".join(HAZ_LIST)
    prod_opts = "; ".join(PROD_LIST)

    rows = []
    start_time = time.time()

    for i, r in df.iterrows():
        if int(i) in done:
            rows.append(done[int(i)])
            continue

        prompt = PROMPT_TEMPLATE.format(
            haz_opts=haz_opts,
            prod_opts=prod_opts,
            title=str(r.get("title", "")),
            text=str(r.get("text", ""))
        )

        t0 = time.time()
        try:
            out = run_ollama(prompt)
            haz_pred, prod_pred, parse_ok, haz_ok, prod_ok = parse_two_lines(out)
            err = ""
        except Exception as e:
            out = ""
            haz_pred, prod_pred, parse_ok, haz_ok, prod_ok = None, None, False, False, False
            err = str(e)

        dt = time.time() - t0

        row = {
            "idx": int(i),
            "parse_ok": bool(parse_ok),
            "haz_pred": haz_pred,
            "prod_pred": prod_pred,
            "haz_in_list": bool(haz_ok),
            "prod_in_list": bool(prod_ok),
            # these may not exist in test; safe:
            "haz_true": r.get("hazard-category", None),
            "prod_true": r.get("product-category", None),
            "latency_sec": round(dt, 3),
            "error": err,
            "raw_output": out[:1500]
        }
        rows.append(row)

        if (i + 1) % 10 == 0:
            elapsed = time.time() - start_time
            print(f"[{i+1}/{n}] parse_ok={parse_ok} haz={haz_pred} prod={prod_pred} (elapsed {elapsed/60:.1f} min)")

        if (i + 1) % SAVE_EVERY == 0:
            pd.DataFrame(rows).to_csv(OUT_CSV, index=False)

    out_df = pd.DataFrame(rows)
    out_df.to_csv(OUT_CSV, index=False)
    print(f"\nSaved final: {OUT_CSV}")

    print("\nParse OK rate:", out_df["parse_ok"].mean())
    print("Hazard in-list rate:", out_df["haz_in_list"].mean())
    print("Product in-list rate:", out_df["prod_in_list"].mean())
    print("Avg latency (sec):", out_df["latency_sec"].mean())

    compute_metrics_if_labels_exist(out_df)


if __name__ == "__main__":
    main()
# Out:
# Loaded 997 rows from incidents_test.csv
# [10/997] parse_ok=True haz=biological prod=meat, egg and dairy products (elapsed 0.3 min)
# [20/997] parse_ok=True haz=biological prod=cereals and bakery products (elapsed 0.4 min)
# [30/997] parse_ok=True haz=foreign bodies prod=non-alcoholic beverages (elapsed 0.5 min)
# [40/997] parse_ok=True haz=allergens prod=prepared dishes and snacks (elapsed 0.6 min)
# [50/997] parse_ok=True haz=chemical prod=meat, egg and dairy products (elapsed 0.7 min)
# [60/997] parse_ok=True haz=foreign bodies prod=meat, egg and dairy products (elapsed 0.8 min)
# [70/997] parse_ok=True haz=biological prod=prepared dishes and snacks (elapsed 0.9 min)
# [80/997] parse_ok=True haz=allergens prod=prepared dishes and snacks (elapsed 1.0 min)
# [90/997] parse_ok=True haz=biological prod=prepared dishes and snacks (elapsed 1.0 min)
# [100/997] parse_ok=True haz=biological prod=nuts, nut products and seeds (elapsed 1.1 min)
# [110/997] parse_ok=True haz=biological prod=prepared dishes and snacks (elapsed 1.2 min)
# [120/997] parse_ok=True haz=allergens prod=confectionery (elapsed 1.3 min)
# [130/997] parse_ok=True haz=foreign bodies prod=cereals and bakery products (elapsed 1.4 min)
# [140/997] parse_ok=True haz=biological prod=meat, egg and dairy products (elapsed 1.5 min)
# [150/997] parse_ok=True haz=allergens prod=prepared dishes and snacks (elapsed 1.6 min)
# [160/997] parse_ok=True haz=allergens prod=confectionery (elapsed 1.7 min)
# [170/997] parse_ok=True haz=biological prod=nuts, nut products and seeds (elapsed 1.8 min)
# [180/997] parse_ok=True haz=allergens prod=prepared dishes and snacks (elapsed 1.9 min)
# [190/997] parse_ok=True haz=biological prod=prepared dishes and snacks (elapsed 2.1 min)
# [200/997] parse_ok=True haz=allergens prod=prepared dishes and snacks (elapsed 2.2 min)
# [210/997] parse_ok=True haz=allergens prod=prepared dishes and snacks (elapsed 2.3 min)
# [220/997] parse_ok=True haz=biological prod=meat, egg and dairy products (elapsed 2.4 min)
# [230/997] parse_ok=True haz=food additives and flavourings prod=confectionery (elapsed 2.5 min)
# [240/997] parse_ok=True haz=allergens prod=prepared dishes and snacks (elapsed 2.6 min)
# [250/997] parse_ok=True haz=packaging defect prod=alcoholic beverages (elapsed 2.7 min)
# [260/997] parse_ok=True haz=foreign bodies prod=prepared dishes and snacks (elapsed 2.8 min)
# [270/997] parse_ok=True haz=allergens prod=prepared dishes and snacks (elapsed 2.9 min)
# [280/997] parse_ok=True haz=allergens prod=confectionery (elapsed 3.0 min)
# [290/997] parse_ok=True haz=allergens prod=prepared dishes and snacks (elapsed 3.1 min)
# [300/997] parse_ok=True haz=biological prod=prepared dishes and snacks (elapsed 3.2 min)
# [310/997] parse_ok=True haz=allergens prod=prepared dishes and snacks (elapsed 3.3 min)
# [320/997] parse_ok=True haz=allergens prod=meat, egg and dairy products (elapsed 3.4 min)
# [330/997] parse_ok=True haz=biological prod=nuts, nut products and seeds (elapsed 3.5 min)
# [340/997] parse_ok=True haz=biological prod=prepared dishes and snacks (elapsed 3.7 min)
# [350/997] parse_ok=True haz=biological prod=prepared dishes and snacks (elapsed 3.9 min)
# [360/997] parse_ok=True haz=fraud prod=meat, egg and dairy products (elapsed 4.0 min)
# [370/997] parse_ok=True haz=foreign bodies prod=prepared dishes and snacks (elapsed 4.1 min)
# [380/997] parse_ok=True haz=biological prod=prepared dishes and snacks (elapsed 4.2 min)
# [390/997] parse_ok=True haz=allergens prod=prepared dishes and snacks (elapsed 4.3 min)
# [400/997] parse_ok=True haz=foreign bodies prod=prepared dishes and snacks (elapsed 4.5 min)
# [410/997] parse_ok=True haz=biological prod=prepared dishes and snacks (elapsed 4.6 min)
# [420/997] parse_ok=True haz=foreign bodies prod=confectionery (elapsed 4.7 min)
# [430/997] parse_ok=True haz=allergens prod=prepared dishes and snacks (elapsed 4.8 min)
# [440/997] parse_ok=True haz=other hazard prod=meat, egg and dairy products (elapsed 4.9 min)
# [450/997] parse_ok=True haz=biological prod=meat, egg and dairy products (elapsed 5.0 min)
# [460/997] parse_ok=True haz=biological prod=meat, egg and dairy products (elapsed 5.1 min)
# [470/997] parse_ok=True haz=allergens prod=other food product / mixed (elapsed 5.2 min)
# [480/997] parse_ok=True haz=biological prod=meat, egg and dairy products (elapsed 5.3 min)
# [490/997] parse_ok=True haz=allergens prod=cereals and bakery products (elapsed 5.5 min)
# [500/997] parse_ok=True haz=biological prod=prepared dishes and snacks (elapsed 5.6 min)
# [510/997] parse_ok=True haz=biological prod=prepared dishes and snacks (elapsed 5.7 min)
# [520/997] parse_ok=True haz=allergens prod=prepared dishes and snacks (elapsed 6.0 min)
# [530/997] parse_ok=True haz=biological prod=meat, egg and dairy products (elapsed 6.1 min)
# [540/997] parse_ok=False haz=other hazard prod=None (elapsed 6.2 min)
# [550/997] parse_ok=True haz=biological prod=prepared dishes and snacks (elapsed 6.3 min)
# [560/997] parse_ok=True haz=biological prod=meat, egg and dairy products (elapsed 6.4 min)
# [570/997] parse_ok=True haz=biological prod=meat, egg and dairy products (elapsed 6.5 min)
# [580/997] parse_ok=True haz=allergens prod=prepared dishes and snacks (elapsed 6.6 min)
# [590/997] parse_ok=True haz=foreign bodies prod=meat, egg and dairy products (elapsed 6.7 min)
# [600/997] parse_ok=True haz=biological prod=prepared dishes and snacks (elapsed 6.9 min)
# [610/997] parse_ok=True haz=biological prod=prepared dishes and snacks (elapsed 7.0 min)
# [620/997] parse_ok=True haz=foreign bodies prod=prepared dishes and snacks (elapsed 7.1 min)
# [630/997] parse_ok=True haz=allergens prod=food additives and flavourings (elapsed 7.2 min)
# [640/997] parse_ok=True haz=biological prod=meat, egg and dairy products (elapsed 7.3 min)
# [650/997] parse_ok=True haz=foreign bodies prod=other food product / mixed (elapsed 7.4 min)
# [660/997] parse_ok=True haz=allergens prod=other food product / mixed (elapsed 7.5 min)
# [670/997] parse_ok=True haz=allergens prod=prepared dishes and snacks (elapsed 7.6 min)
# [680/997] parse_ok=True haz=allergens prod=prepared dishes and snacks (elapsed 7.7 min)
# [690/997] parse_ok=True haz=biological prod=prepared dishes and snacks (elapsed 7.8 min)
# [700/997] parse_ok=False haz=None prod=None (elapsed 8.1 min)
# [710/997] parse_ok=True haz=biological prod=prepared dishes and snacks (elapsed 8.2 min)
# [720/997] parse_ok=True haz=allergens prod=prepared dishes and snacks (elapsed 8.3 min)
# [730/997] parse_ok=True haz=biological prod=prepared dishes and snacks (elapsed 8.4 min)
# [740/997] parse_ok=True haz=allergens prod=prepared dishes and snacks (elapsed 8.5 min)
# [750/997] parse_ok=True haz=biological prod=fruits and vegetables (elapsed 8.6 min)
# [760/997] parse_ok=True haz=foreign bodies prod=prepared dishes and snacks (elapsed 8.7 min)
# [770/997] parse_ok=True haz=biological prod=meat, egg and dairy products (elapsed 8.8 min)
# [780/997] parse_ok=True haz=allergens prod=prepared dishes and snacks (elapsed 9.0 min)
# [790/997] parse_ok=True haz=allergens prod=other food product / mixed (elapsed 9.1 min)
# [800/997] parse_ok=True haz=biological prod=meat, egg and dairy products (elapsed 9.2 min)
# [810/997] parse_ok=True haz=biological prod=prepared dishes and snacks (elapsed 9.3 min)
# [820/997] parse_ok=True haz=biological prod=prepared dishes and snacks (elapsed 9.4 min)
# [830/997] parse_ok=True haz=allergens prod=confectionery (elapsed 9.5 min)
# [840/997] parse_ok=True haz=chemical prod=meat, egg and dairy products (elapsed 9.6 min)
# [850/997] parse_ok=True haz=chemical prod=non-alcoholic beverages (elapsed 9.7 min)
# [860/997] parse_ok=True haz=allergens prod=confectionery (elapsed 9.8 min)
# [870/997] parse_ok=True haz=allergens prod=prepared dishes and snacks (elapsed 9.9 min)
# [880/997] parse_ok=True haz=allergens prod=prepared dishes and snacks (elapsed 10.0 min)
# [890/997] parse_ok=True haz=allergens prod=prepared dishes and snacks (elapsed 10.1 min)
# [900/997] parse_ok=True haz=allergens prod=prepared dishes and snacks (elapsed 10.2 min)
# [910/997] parse_ok=True haz=chemical prod=prepared dishes and snacks (elapsed 10.3 min)
# [920/997] parse_ok=True haz=biological prod=meat, egg and dairy products (elapsed 10.4 min)
# [930/997] parse_ok=True haz=allergens prod=cereals and bakery products (elapsed 10.5 min)
# [940/997] parse_ok=True haz=biological prod=meat, egg and dairy products (elapsed 10.6 min)
# [950/997] parse_ok=True haz=biological prod=prepared dishes and snacks (elapsed 10.8 min)
# [960/997] parse_ok=True haz=biological prod=meat, egg and dairy products (elapsed 10.8 min)
# [970/997] parse_ok=True haz=allergens prod=prepared dishes and snacks (elapsed 11.0 min)
# [980/997] parse_ok=True haz=allergens prod=dietetic foods, food supplements, fortified foods (elapsed 11.1 min)
# [990/997] parse_ok=True haz=allergens prod=other food product / mixed (elapsed 11.2 min)
#
# Saved final: results\zero_shot_test_all_strict.csv
#
# Parse OK rate: 0.9909729187562688
# Hazard in-list rate: 0.9929789368104313
# Product in-list rate: 0.9909729187562688
# Avg latency (sec): 0.6757853560682047
#
# === Hazard-category Metrics (on parse_ok samples: 988/997) ===
# Accuracy: 0.8866396761133604
# Macro-F1: 0.5980953772597644
# Micro-F1: 0.8866396761133604
# Weighted-F1: 0.8738251794241235
#
# Classification Report:
#
#                                 precision    recall  f1-score   support
#
#                      allergens       0.94      0.97      0.95       365
#                     biological       0.90      0.99      0.94       338
#                       chemical       0.78      0.78      0.78        50
# food additives and flavourings       0.33      0.50      0.40         4
#                 foreign bodies       0.91      0.95      0.93       110
#                          fraud       0.87      0.35      0.50        75
#                      migration       0.00      0.00      0.00         1
#           organoleptic aspects       0.62      0.50      0.56        10
#                   other hazard       0.24      0.19      0.21        26
#               packaging defect       1.00      0.56      0.71         9
#
#                       accuracy                           0.89       988
#                      macro avg       0.66      0.58      0.60       988
#                   weighted avg       0.88      0.89      0.87       988
#
#
# === Product-category Metrics (on parse_ok samples: 988/997) ===
# Accuracy: 0.37550607287449395
# Macro-F1: 0.388499730894979
# Micro-F1: 0.37550607287449395
# Weighted-F1: 0.3767647653077403
#
# Classification Report:
#
#                                                    precision    recall  f1-score   support
#
#                               alcoholic beverages       1.00      0.75      0.86        16
#                       cereals and bakery products       0.76      0.16      0.26       121
#      cocoa and cocoa preparations, coffee and tea       0.00      0.00      0.00        40
#                                     confectionery       0.19      0.45      0.26        33
# dietetic foods, food supplements, fortified foods       0.89      0.31      0.46        26
#                                     fats and oils       0.80      0.80      0.80         5
#                    food additives and flavourings       0.20      0.25      0.22         4
#                             fruits and vegetables       0.94      0.15      0.25       103
#                                  herbs and spices       0.25      0.05      0.09        19
#                             honey and royal jelly       0.00      0.00      0.00         2
#                                 ices and desserts       1.00      0.10      0.19        49
#                      meat, egg and dairy products       0.77      0.59      0.67       279
#                           non-alcoholic beverages       0.63      0.63      0.63        19
#                      nuts, nut products and seeds       0.96      0.45      0.62        53
#                        other food product / mixed       0.09      0.15      0.11        13
#                                          pet feed       1.00      1.00      1.00         2
#                        prepared dishes and snacks       0.15      0.90      0.26        92
#                                           seafood       0.75      0.05      0.10        59
#              soups, broths, sauces and condiments       0.00      0.00      0.00        52
#                                 sugars and syrups       1.00      1.00      1.00         1
#
#                                          accuracy                           0.38       988
#                                         macro avg       0.57      0.39      0.39       988
#                                      weighted avg       0.64      0.38      0.38       988
