# %%
import pandas as pd
import subprocess, re, time
from pathlib import Path
from sklearn.metrics import classification_report, accuracy_score, f1_score

# ----------------------------
# Config
# ----------------------------
MODEL = "llama3.1:8b"
TRAIN_CSV = "incidents_train.csv"
TEST_CSV  = "incidents_test.csv"   # <-- test

OUT_DIR = Path("results")
OUT_DIR.mkdir(exist_ok=True)

# new output (targeted few-shot 4 examples)
OUT_CSV = OUT_DIR / "few_shot4_test_strict_stdin_canon.csv"  # <-- test output

SAVE_EVERY = 20
SEED = 42

HAZ_LIST = [
    "allergens", "biological", "chemical", "food additives and flavourings",
    "foreign bodies", "fraud", "migration", "organoleptic aspects",
    "other hazard", "packaging defect"
]

PROD_LIST = [
    "alcoholic beverages", "cereals and bakery products",
    "cocoa and cocoa preparations, coffee and tea", "confectionery",
    "dietetic foods, food supplements, fortified foods", "fats and oils",
    "feed materials", "food additives and flavourings", "food contact materials",
    "fruits and vegetables", "herbs and spices", "honey and royal jelly",
    "ices and desserts", "meat, egg and dairy products", "non-alcoholic beverages",
    "nuts, nut products and seeds", "other food product / mixed", "pet feed",
    "prepared dishes and snacks", "seafood",
    "soups, broths, sauces and condiments", "sugars and syrups"
]

# ----------------------------
# Ollama runner (stdin + timeout)  ✅ Windows-safe for long prompts
# ----------------------------
def run_ollama(prompt: str, timeout_sec: int = 180) -> str:
    try:
        res = subprocess.run(
            ["ollama", "run", MODEL],
            input=prompt,
            capture_output=True,
            text=True,
            encoding="utf-8",
            errors="replace",
            timeout=timeout_sec
        )
    except subprocess.TimeoutExpired:
        raise RuntimeError(f"ollama timeout after {timeout_sec}s")

    if res.returncode != 0:
        raise RuntimeError(f"ollama error: {res.stderr[:800]}")

    out = (res.stdout or "").strip()
    if not out:
        raise RuntimeError(f"empty output (stderr={res.stderr[:300]})")
    return out

# ----------------------------
# Parser (strict + canonicalization)
# ----------------------------
def parse_two_lines(out: str):
    haz = None
    prod = None

    m1 = re.search(r"hazard-category\s*:\s*(.+)", out, flags=re.IGNORECASE)
    m2 = re.search(r"product-category\s*:\s*(.+)", out, flags=re.IGNORECASE)

    if m1:
        haz = m1.group(1).strip()
    if m2:
        prod = m2.group(1).strip()

    HAZ_CANON = {
        "food additives and flavorings": "food additives and flavourings",
        "food additives & flavourings": "food additives and flavourings",
        "food additives & flavorings": "food additives and flavourings",
        "foreign body": "foreign bodies",
        "packaging defects": "packaging defect",
        "organoleptic": "organoleptic aspects",
        "other hazards": "other hazard",
    }

    PROD_CANON = {
        "non alcoholic beverages": "non-alcoholic beverages",
        "nonalcoholic beverages": "non-alcoholic beverages",
        "cocoa, coffee and tea": "cocoa and cocoa preparations, coffee and tea",
        "cocoa and coffee and tea": "cocoa and cocoa preparations, coffee and tea",
        "other food product/mixed": "other food product / mixed",
        "other food product /mixed": "other food product / mixed",
        "other food product mixed": "other food product / mixed",
        "meat egg and dairy products": "meat, egg and dairy products",
        "soups broths sauces and condiments": "soups, broths, sauces and condiments",
        "food contact material": "food contact materials",
    }

    def norm(x):
        if x is None:
            return None
        x = x.strip().strip('"').strip("'").strip()
        x = re.sub(r"\s+", " ", x)
        x = x.rstrip(" .,:;")
        return x

    def canonize(x, canon_map):
        if x is None:
            return None
        key = x.lower().strip()
        return canon_map.get(key, x)

    haz = canonize(norm(haz), HAZ_CANON)
    prod = canonize(norm(prod), PROD_CANON)

    haz_in_list = (haz in HAZ_LIST) if haz else False
    prod_in_list = (prod in PROD_LIST) if prod else False

    if not haz_in_list:
        haz = None
    if not prod_in_list:
        prod = None

    parse_ok = (haz is not None) and (prod is not None)
    return haz, prod, parse_ok, haz_in_list, prod_in_list

# ----------------------------
# Metrics (skip if test has no labels)
# ----------------------------
def compute_metrics_if_possible(df_res: pd.DataFrame, true_col: str, pred_col: str, title: str):
    if true_col not in df_res.columns:
        print(f"\n=== {title} Metrics ===\nNo ground-truth column '{true_col}'. Skipping.")
        return
    if df_res[true_col].isna().all():
        print(f"\n=== {title} Metrics ===\nGround-truth '{true_col}' is empty. Skipping.")
        return

    df_ok = df_res[df_res["parse_ok"] == True].copy()
    if len(df_ok) == 0:
        print(f"\n=== {title} Metrics ===\nNo parse_ok samples.")
        return

    y_true = df_ok[true_col].astype(str)
    y_pred = df_ok[pred_col].astype(str)

    acc = accuracy_score(y_true, y_pred)
    macro = f1_score(y_true, y_pred, average="macro", zero_division=0)
    micro = f1_score(y_true, y_pred, average="micro", zero_division=0)
    weighted = f1_score(y_true, y_pred, average="weighted", zero_division=0)

    print(f"\n=== {title} Metrics (on parse_ok samples: {len(df_ok)}/{len(df_res)}) ===")
    print("Accuracy:", acc)
    print("Macro-F1:", macro)
    print("Micro-F1:", micro)
    print("Weighted-F1:", weighted)
    print("\nClassification Report:\n")
    print(classification_report(y_true, y_pred, zero_division=0))

# ----------------------------
# Targeted 4-shot builder
# ----------------------------
def _fmt_example(ex) -> str:
    return (
        "Example:\n"
        f"Report:\nTitle: {str(ex['title'])}\nText: {str(ex['text'])}\n"
        f"Output:\nhazard-category: {ex['hazard-category']}\nproduct-category: {ex['product-category']}\n"
    )

def pick_one(train: pd.DataFrame, hazard_cat: str = None, prod_cat: str = None, seed: int = 0):
    sub = train
    if hazard_cat is not None:
        sub = sub[sub["hazard-category"] == hazard_cat]
    if prod_cat is not None:
        sub = sub[sub["product-category"] == prod_cat]
    if len(sub) == 0:
        return None
    return sub.sample(1, random_state=seed).iloc[0]

def build_few_shot4_block(train: pd.DataFrame) -> str:
    """
    4 targeted examples to address known weak spots:
    - fraud (hazard)
    - organoleptic aspects (hazard)
    - soups/broths/sauces (product)
    - cocoa/coffee/tea (product)
    """
    ex = []

    r1 = pick_one(train, hazard_cat="fraud", seed=SEED)
    if r1 is not None: ex.append(r1)

    r2 = pick_one(train, hazard_cat="organoleptic aspects", seed=SEED + 1)
    if r2 is not None: ex.append(r2)

    r3 = pick_one(train, prod_cat="soups, broths, sauces and condiments", seed=SEED + 2)
    if r3 is not None: ex.append(r3)

    r4 = pick_one(train, prod_cat="cocoa and cocoa preparations, coffee and tea", seed=SEED + 3)
    if r4 is not None: ex.append(r4)

    seen = set()
    blocks = []
    for row in ex:
        key = (str(row["title"]), str(row["text"]))
        if key in seen:
            continue
        seen.add(key)
        blocks.append(_fmt_example(row))

    return "\n".join(blocks)

# ----------------------------
# Main
# ----------------------------
def main():
    train = pd.read_csv(TRAIN_CSV)
    test = pd.read_csv(TEST_CSV)
    n = len(test)
    print(f"Loaded train={len(train)} test={n}")

    few_shot_examples = build_few_shot4_block(train)
    if not few_shot_examples.strip():
        print("ERROR: Could not build few-shot examples (missing target classes in train?).")
        return

    haz_opts = "; ".join(HAZ_LIST)
    prod_opts = "; ".join(PROD_LIST)

    PROMPT_TEMPLATE = f"""You are a food safety incident classifier.

Choose labels ONLY from the allowed lists.
Do NOT invent new labels.

Output ONLY two lines, no extra text.
Line1 must be: hazard-category: <one of: {haz_opts}>
Line2 must be: product-category: <one of: {prod_opts}>

Here are labeled examples:
{few_shot_examples}

Now classify this new report:
Report:
Title: {{title}}
Text: {{text}}
""".strip()

    # Sanity check
    print("\nSanity check (single call)...")
    sanity_prompt = (
        "You MUST output ONLY two lines, no extra text.\n"
        "Line1 must be: hazard-category: allergens\n"
        "Line2 must be: product-category: confectionery\n"
    )
    try:
        sanity_out = run_ollama(sanity_prompt, timeout_sec=120)
        print("Sanity output:\n", sanity_out[:400], "\n")
    except Exception as e:
        print("Sanity check failed:", str(e))
        print("Fix Ollama/model first (e.g., `ollama pull llama3.1:8b`, then `ollama run llama3.1:8b`).")
        return

    # resume support
    done = {}
    if OUT_CSV.exists():
        prev = pd.read_csv(OUT_CSV)
        for _, r in prev.iterrows():
            done[int(r["idx"])] = r.to_dict()
        print(f"Resuming: found {len(done)} already processed rows in {OUT_CSV}")

    rows = []
    start = time.time()

    for i, r in test.iterrows():
        if int(i) in done:
            rows.append(done[int(i)])
            continue

        prompt = PROMPT_TEMPLATE.format(title=str(r.get("title", "")), text=str(r.get("text", "")))
        t0 = time.time()
        try:
            out = run_ollama(prompt, timeout_sec=180)
            haz_pred, prod_pred, parse_ok, haz_ok, prod_ok = parse_two_lines(out)
            err = ""
        except Exception as e:
            out = ""
            haz_pred, prod_pred, parse_ok, haz_ok, prod_ok = None, None, False, False, False
            err = str(e)

        dt = time.time() - t0

        rows.append({
            "idx": int(i),
            "parse_ok": bool(parse_ok),
            "haz_pred": haz_pred,
            "prod_pred": prod_pred,
            "haz_in_list": bool(haz_ok),
            "prod_in_list": bool(prod_ok),
            # if your test has labels, these exist; otherwise None
            "haz_true": r.get("hazard-category", None),
            "prod_true": r.get("product-category", None),
            "latency_sec": round(dt, 3),
            "error": err,
            "raw_output": out[:1500]
        })

        if (i + 1) % 10 == 0:
            elapsed = time.time() - start
            print(f"[{i+1}/{n}] parse_ok={parse_ok} haz={haz_pred} prod={prod_pred} (elapsed {elapsed/60:.1f} min)")

        if (i + 1) % SAVE_EVERY == 0:
            pd.DataFrame(rows).to_csv(OUT_CSV, index=False)

    out_df = pd.DataFrame(rows)
    out_df.to_csv(OUT_CSV, index=False)
    print(f"\nSaved final: {OUT_CSV}")

    print("\nParse OK rate:", out_df["parse_ok"].mean())
    print("Hazard in-list rate:", out_df["haz_in_list"].mean())
    print("Product in-list rate:", out_df["prod_in_list"].mean())
    print("Avg latency (sec):", out_df["latency_sec"].mean())

    compute_metrics_if_possible(out_df, "haz_true", "haz_pred", "Hazard-category")
    compute_metrics_if_possible(out_df, "prod_true", "prod_pred", "Product-category")

if __name__ == "__main__":
    main()
# Out:
# Loaded train=5082 test=997
#
# Sanity check (single call)...
# Sanity output:
#  hazard-category: allergens
# product-category: confectionery
#
# [10/997] parse_ok=True haz=biological prod=meat, egg and dairy products (elapsed 0.1 min)
# [20/997] parse_ok=True haz=biological prod=cereals and bakery products (elapsed 0.3 min)
# [30/997] parse_ok=True haz=foreign bodies prod=alcoholic beverages (elapsed 0.4 min)
# [40/997] parse_ok=True haz=allergens prod=other food product / mixed (elapsed 0.5 min)
# [50/997] parse_ok=True haz=biological prod=meat, egg and dairy products (elapsed 0.5 min)
# [60/997] parse_ok=True haz=foreign bodies prod=meat, egg and dairy products (elapsed 0.6 min)
# [70/997] parse_ok=True haz=biological prod=ices and desserts (elapsed 0.8 min)
# [80/997] parse_ok=True haz=allergens prod=ices and desserts (elapsed 0.9 min)
# [90/997] parse_ok=True haz=biological prod=meat, egg and dairy products (elapsed 1.0 min)
# [100/997] parse_ok=True haz=biological prod=nuts, nut products and seeds (elapsed 1.1 min)
# [110/997] parse_ok=True haz=biological prod=prepared dishes and snacks (elapsed 1.1 min)
# [120/997] parse_ok=True haz=allergens prod=confectionery (elapsed 1.2 min)
# [130/997] parse_ok=True haz=foreign bodies prod=prepared dishes and snacks (elapsed 1.3 min)
# [140/997] parse_ok=True haz=biological prod=meat, egg and dairy products (elapsed 1.6 min)
# [150/997] parse_ok=True haz=allergens prod=meat, egg and dairy products (elapsed 1.7 min)
# [160/997] parse_ok=True haz=allergens prod=confectionery (elapsed 1.8 min)
# [170/997] parse_ok=True haz=biological prod=nuts, nut products and seeds (elapsed 1.9 min)
# [180/997] parse_ok=True haz=allergens prod=prepared dishes and snacks (elapsed 2.0 min)
# [190/997] parse_ok=True haz=biological prod=prepared dishes and snacks (elapsed 2.2 min)
# [200/997] parse_ok=True haz=allergens prod=meat, egg and dairy products (elapsed 2.3 min)
# [210/997] parse_ok=True haz=allergens prod=dietetic foods, food supplements, fortified foods (elapsed 2.5 min)
# [220/997] parse_ok=True haz=biological prod=meat, egg and dairy products (elapsed 2.6 min)
# [230/997] parse_ok=True haz=allergens prod=nuts, nut products and seeds (elapsed 2.7 min)
# [240/997] parse_ok=True haz=allergens prod=meat, egg and dairy products (elapsed 2.8 min)
# [250/997] parse_ok=True haz=packaging defect prod=alcoholic beverages (elapsed 2.9 min)
# [260/997] parse_ok=False haz=foreign bodies prod=None (elapsed 3.0 min)
# [270/997] parse_ok=True haz=allergens prod=soups, broths, sauces and condiments (elapsed 3.1 min)
# [280/997] parse_ok=True haz=allergens prod=confectionery (elapsed 3.2 min)
# [290/997] parse_ok=True haz=allergens prod=prepared dishes and snacks (elapsed 3.3 min)
# [300/997] parse_ok=True haz=foreign bodies prod=other food product / mixed (elapsed 3.4 min)
# [310/997] parse_ok=True haz=allergens prod=cereals and bakery products (elapsed 3.5 min)
# [320/997] parse_ok=True haz=allergens prod=meat, egg and dairy products (elapsed 3.6 min)
# [330/997] parse_ok=True haz=biological prod=nuts, nut products and seeds (elapsed 3.8 min)
# [340/997] parse_ok=True haz=biological prod=nuts, nut products and seeds (elapsed 3.9 min)
# [350/997] parse_ok=True haz=biological prod=nuts, nut products and seeds (elapsed 4.1 min)
# [360/997] parse_ok=True haz=fraud prod=meat, egg and dairy products (elapsed 4.2 min)
# [370/997] parse_ok=True haz=foreign bodies prod=prepared dishes and snacks (elapsed 4.4 min)
# [380/997] parse_ok=True haz=biological prod=fats and oils (elapsed 4.5 min)
# [390/997] parse_ok=True haz=allergens prod=prepared dishes and snacks (elapsed 4.6 min)
# [400/997] parse_ok=True haz=foreign bodies prod=prepared dishes and snacks (elapsed 4.7 min)
# [410/997] parse_ok=True haz=biological prod=meat, egg and dairy products (elapsed 4.8 min)
# [420/997] parse_ok=True haz=foreign bodies prod=confectionery (elapsed 4.9 min)
# [430/997] parse_ok=True haz=allergens prod=prepared dishes and snacks (elapsed 5.0 min)
# [440/997] parse_ok=True haz=foreign bodies prod=seafood (elapsed 5.1 min)
# [450/997] parse_ok=True haz=biological prod=meat, egg and dairy products (elapsed 5.3 min)
# [460/997] parse_ok=True haz=biological prod=meat, egg and dairy products (elapsed 5.4 min)
# [470/997] parse_ok=True haz=allergens prod=cereals and bakery products (elapsed 5.5 min)
# [480/997] parse_ok=True haz=biological prod=meat, egg and dairy products (elapsed 5.6 min)
# [490/997] parse_ok=True haz=allergens prod=cereals and bakery products (elapsed 5.8 min)
# [500/997] parse_ok=True haz=biological prod=prepared dishes and snacks (elapsed 5.9 min)
# [510/997] parse_ok=True haz=biological prod=meat, egg and dairy products (elapsed 6.0 min)
# [520/997] parse_ok=True haz=allergens prod=seafood (elapsed 6.3 min)
# [530/997] parse_ok=True haz=biological prod=meat, egg and dairy products (elapsed 6.4 min)
# [540/997] parse_ok=True haz=packaging defect prod=cocoa and cocoa preparations, coffee and tea (elapsed 6.6 min)
# [550/997] parse_ok=True haz=biological prod=fruits and vegetables (elapsed 6.7 min)
# [560/997] parse_ok=True haz=biological prod=meat, egg and dairy products (elapsed 6.8 min)
# [570/997] parse_ok=True haz=biological prod=meat, egg and dairy products (elapsed 6.9 min)
# [580/997] parse_ok=True haz=allergens prod=nuts, nut products and seeds (elapsed 7.0 min)
# [590/997] parse_ok=True haz=foreign bodies prod=meat, egg and dairy products (elapsed 7.1 min)
# [600/997] parse_ok=True haz=biological prod=fruits and vegetables (elapsed 7.2 min)
# [610/997] parse_ok=True haz=biological prod=meat, egg and dairy products (elapsed 7.3 min)
# [620/997] parse_ok=True haz=foreign bodies prod=prepared dishes and snacks (elapsed 7.5 min)
# [630/997] parse_ok=True haz=allergens prod=food additives and flavourings (elapsed 7.6 min)
# [640/997] parse_ok=True haz=biological prod=meat, egg and dairy products (elapsed 7.7 min)
# [650/997] parse_ok=True haz=foreign bodies prod=other food product / mixed (elapsed 7.8 min)
# [660/997] parse_ok=True haz=allergens prod=dietetic foods, food supplements, fortified foods (elapsed 7.9 min)
# [670/997] parse_ok=True haz=allergens prod=ices and desserts (elapsed 8.0 min)
# [680/997] parse_ok=True haz=allergens prod=meat, egg and dairy products (elapsed 8.1 min)
# [690/997] parse_ok=True haz=biological prod=ices and desserts (elapsed 8.3 min)
# [700/997] parse_ok=False haz=None prod=None (elapsed 8.5 min)
# [710/997] parse_ok=True haz=biological prod=prepared dishes and snacks (elapsed 8.7 min)
# [720/997] parse_ok=True haz=allergens prod=cereals and bakery products (elapsed 8.8 min)
# [730/997] parse_ok=True haz=biological prod=prepared dishes and snacks (elapsed 8.9 min)
# [740/997] parse_ok=True haz=allergens prod=soups, broths, sauces and condiments (elapsed 9.0 min)
# [750/997] parse_ok=True haz=biological prod=fruits and vegetables (elapsed 9.1 min)
# [760/997] parse_ok=True haz=foreign bodies prod=prepared dishes and snacks (elapsed 9.2 min)
# [770/997] parse_ok=True haz=fraud prod=meat, egg and dairy products (elapsed 9.3 min)
# [780/997] parse_ok=True haz=allergens prod=nuts, nut products and seeds (elapsed 9.5 min)
# [790/997] parse_ok=True haz=allergens prod=dietetic foods, food supplements, fortified foods (elapsed 9.6 min)
# [800/997] parse_ok=True haz=biological prod=meat, egg and dairy products (elapsed 9.7 min)
# [810/997] parse_ok=True haz=biological prod=seafood (elapsed 9.8 min)
# [820/997] parse_ok=True haz=biological prod=meat, egg and dairy products (elapsed 9.9 min)
# [830/997] parse_ok=True haz=allergens prod=nuts, nut products and seeds (elapsed 10.0 min)
# [840/997] parse_ok=True haz=chemical prod=meat, egg and dairy products (elapsed 10.1 min)
# [850/997] parse_ok=True haz=chemical prod=cocoa and cocoa preparations, coffee and tea (elapsed 10.2 min)
# [860/997] parse_ok=True haz=allergens prod=nuts, nut products and seeds (elapsed 10.3 min)
# [870/997] parse_ok=True haz=allergens prod=nuts, nut products and seeds (elapsed 10.4 min)
# [880/997] parse_ok=True haz=allergens prod=prepared dishes and snacks (elapsed 10.6 min)
# [890/997] parse_ok=True haz=organoleptic aspects prod=ices and desserts (elapsed 10.7 min)
# [900/997] parse_ok=True haz=allergens prod=nuts, nut products and seeds (elapsed 10.8 min)
# [910/997] parse_ok=True haz=allergens prod=meat, egg and dairy products (elapsed 10.9 min)
# [920/997] parse_ok=True haz=biological prod=meat, egg and dairy products (elapsed 11.0 min)
# [930/997] parse_ok=True haz=allergens prod=cereals and bakery products (elapsed 11.1 min)
# [940/997] parse_ok=True haz=biological prod=meat, egg and dairy products (elapsed 11.2 min)
# [950/997] parse_ok=True haz=biological prod=fruits and vegetables (elapsed 11.3 min)
# [960/997] parse_ok=True haz=biological prod=meat, egg and dairy products (elapsed 11.4 min)
# [970/997] parse_ok=True haz=allergens prod=prepared dishes and snacks (elapsed 11.5 min)
# [980/997] parse_ok=True haz=allergens prod=dietetic foods, food supplements, fortified foods (elapsed 11.6 min)
# [990/997] parse_ok=True haz=allergens prod=herbs and spices (elapsed 11.7 min)
#
# Saved final: results\few_shot4_test_strict_stdin_canon.csv
#
# Parse OK rate: 0.9779338014042126
# Hazard in-list rate: 0.9869608826479438
# Product in-list rate: 0.9799398194583752
# Avg latency (sec): 0.7099017051153461
#
# === Hazard-category Metrics (on parse_ok samples: 975/997) ===
# Accuracy: 0.8851282051282051
# Macro-F1: 0.5545845389295954
# Micro-F1: 0.8851282051282051
# Weighted-F1: 0.865895089691509
#
# Classification Report:
#
#                                 precision    recall  f1-score   support
#
#                      allergens       0.93      0.98      0.96       361
#                     biological       0.89      0.99      0.94       331
#                       chemical       0.92      0.68      0.78        50
# food additives and flavourings       0.25      0.25      0.25         4
#                 foreign bodies       0.84      0.98      0.90       109
#                          fraud       0.87      0.36      0.50        73
#                      migration       0.00      0.00      0.00         1
#           organoleptic aspects       0.42      0.50      0.45        10
#                   other hazard       0.40      0.08      0.13        26
#               packaging defect       0.67      0.60      0.63        10
#
#                       accuracy                           0.89       975
#                      macro avg       0.62      0.54      0.55       975
#                   weighted avg       0.87      0.89      0.87       975
#
#
# === Product-category Metrics (on parse_ok samples: 975/997) ===
# Accuracy: 0.601025641025641
# Macro-F1: 0.5547069398204945
# Micro-F1: 0.601025641025641
# Weighted-F1: 0.6120471220012997
#
# Classification Report:
#
#                                                    precision    recall  f1-score   support
#
#                               alcoholic beverages       1.00      1.00      1.00        16
#                       cereals and bakery products       0.76      0.24      0.36       119
#      cocoa and cocoa preparations, coffee and tea       0.89      0.20      0.32        41
#                                     confectionery       0.25      0.44      0.31        32
# dietetic foods, food supplements, fortified foods       0.58      0.56      0.57        25
#                                     fats and oils       0.22      0.80      0.35         5
#                                    feed materials       0.00      0.00      0.00         0
#                    food additives and flavourings       0.20      0.25      0.22         4
#                             fruits and vegetables       0.77      0.59      0.67       101
#                                  herbs and spices       0.62      0.42      0.50        19
#                             honey and royal jelly       1.00      0.50      0.67         2
#                                 ices and desserts       0.88      0.77      0.82        48
#                      meat, egg and dairy products       0.82      0.86      0.84       277
#                           non-alcoholic beverages       1.00      0.74      0.85        19
#                      nuts, nut products and seeds       0.55      0.77      0.65        53
#                        other food product / mixed       0.03      0.08      0.04        13
#                                          pet feed       1.00      1.00      1.00         2
#                        prepared dishes and snacks       0.26      0.59      0.36        92
#                                           seafood       0.94      0.55      0.69        55
#              soups, broths, sauces and condiments       1.00      0.27      0.43        51
#                                 sugars and syrups       1.00      1.00      1.00         1
#
#                                          accuracy                           0.60       975
#                                         macro avg       0.66      0.55      0.55       975
#                                      weighted avg       0.73      0.60      0.61       975
