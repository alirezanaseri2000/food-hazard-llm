# %%
import pandas as pd
import subprocess, re, time
from pathlib import Path
from sklearn.metrics import classification_report, accuracy_score, f1_score

MODEL = "llama3.1:8b"
INPUT_CSV = "incidents_valid.csv"

OUT_DIR = Path("results")
OUT_DIR.mkdir(exist_ok=True)

# output file (grounded + extract guidance + canonicalization)
OUT_CSV = OUT_DIR / "zero_shot_valid_grounded_canon.csv"

SAVE_EVERY = 20  # save every N rows

HAZ_LIST = [
    "allergens", "biological", "chemical", "food additives and flavourings",
    "foreign bodies", "fraud", "migration", "organoleptic aspects",
    "other hazard", "packaging defect"
]

PROD_LIST = [
    "alcoholic beverages", "cereals and bakery products",
    "cocoa and cocoa preparations, coffee and tea", "confectionery",
    "dietetic foods, food supplements, fortified foods", "fats and oils",
    "feed materials", "food additives and flavourings", "food contact materials",
    "fruits and vegetables", "herbs and spices", "honey and royal jelly",
    "ices and desserts", "meat, egg and dairy products", "non-alcoholic beverages",
    "nuts, nut products and seeds", "other food product / mixed", "pet feed",
    "prepared dishes and snacks", "seafood",
    "soups, broths, sauces and condiments", "sugars and syrups"
]

PROMPT_TEMPLATE = """You are a food safety incident classifier.

Choose labels ONLY from the allowed lists.
Do NOT invent new labels. If unsure, choose the closest match based on definitions.

Hazard-category definitions (use these):
- allergens: undeclared allergens or allergen contamination.
- biological: pathogenic microorganisms (bacteria/viruses/parasites), spoilage microbes, mycotoxins of biological origin.
- chemical: chemicals, toxins (non-biological), residues, heavy metals, cleaning agents.
- food additives and flavourings: issues specifically about additives/flavourings (unauthorized, excessive, wrong additive).
- foreign bodies: physical objects (plastic, glass, metal, stones).
- fraud: intentional deception (mislabeling, substitution, counterfeit, origin fraud).
- migration: substances migrating from packaging/materials into food.
- organoleptic aspects: abnormal smell/taste/texture/appearance without a clear contaminant.
- other hazard: hazards that do not fit above categories.
- packaging defect: packaging integrity/closure/seal defects causing risk.

Product-category guidance:
Pick the category that best matches the recalled product itself (not the ingredient).
If the product is a meal/ready-to-eat item, prefer "prepared dishes and snacks".
If it is clearly a raw/processed meat/egg/dairy item, prefer "meat, egg and dairy products".

Before choosing labels, internally identify:
- the hazard evidence phrase (e.g., "Listeria", "plastic fragment", "undeclared milk")
- the recalled product phrase (e.g., "ham, sliced", "cookies", "baby formula")
Use those internal findings to select the closest allowed labels.

Output ONLY two lines, no extra text.
Line1 must be: hazard-category: <one of: {haz_opts}>
Line2 must be: product-category: <one of: {prod_opts}>

Report:
Title: {title}
Text: {text}
""".strip()


def run_ollama(prompt: str) -> str:
    res = subprocess.run(
        ["ollama", "run", MODEL, prompt],
        capture_output=True,
        text=True,
        encoding="utf-8",
        errors="replace"
    )
    if res.returncode != 0:
        raise RuntimeError(res.stderr)
    return res.stdout.strip()


def parse_two_lines(out: str):
    """
    STRICT parser + SOFT canonicalization:
    - normalize extracted label text
    - map common spelling/punctuation variants to canonical labels
    - accept ONLY if exact match in label space after canonicalization
    """
    haz = None
    prod = None

    m1 = re.search(r"hazard-category\s*:\s*(.+)", out, flags=re.IGNORECASE)
    m2 = re.search(r"product-category\s*:\s*(.+)", out, flags=re.IGNORECASE)

    if m1:
        haz = m1.group(1).strip()
    if m2:
        prod = m2.group(1).strip()

    # --- canonical maps (lowercased keys) ---
    HAZ_CANON = {
        "food additives and flavorings": "food additives and flavourings",
        "food additives & flavourings": "food additives and flavourings",
        "food additives & flavorings": "food additives and flavourings",
        "foreign body": "foreign bodies",
        "packaging defects": "packaging defect",
        "organoleptic": "organoleptic aspects",
        "other hazards": "other hazard",
    }

    PROD_CANON = {
        "non alcoholic beverages": "non-alcoholic beverages",
        "nonalcoholic beverages": "non-alcoholic beverages",
        "cocoa, coffee and tea": "cocoa and cocoa preparations, coffee and tea",
        "cocoa and coffee and tea": "cocoa and cocoa preparations, coffee and tea",
        "other food product/mixed": "other food product / mixed",
        "other food product /mixed": "other food product / mixed",
        "other food product mixed": "other food product / mixed",
        "meat egg and dairy products": "meat, egg and dairy products",
        "soups broths sauces and condiments": "soups, broths, sauces and condiments",
        "food contact material": "food contact materials",
    }

    def norm(x):
        if x is None:
            return None
        x = x.strip().strip('"').strip("'").strip()
        x = re.sub(r"\s+", " ", x)
        x = x.rstrip(" .,:;")
        return x

    # normalize first
    haz = norm(haz)
    prod = norm(prod)

    # soft canonicalization (only common variants)
    def canonize(x, canon_map):
        if x is None:
            return None
        key = x.lower().strip()
        return canon_map.get(key, x)

    haz = canonize(haz, HAZ_CANON)
    prod = canonize(prod, PROD_CANON)

    # enforce label space
    haz_in_list = (haz in HAZ_LIST) if haz else False
    prod_in_list = (prod in PROD_LIST) if prod else False

    if not haz_in_list:
        haz = None
    if not prod_in_list:
        prod = None

    parse_ok = (haz is not None) and (prod is not None)
    return haz, prod, parse_ok, haz_in_list, prod_in_list


def compute_metrics(df_res: pd.DataFrame, label_col_true: str, label_col_pred: str, title: str):
    df_ok = df_res[df_res["parse_ok"] == True].copy()

    if len(df_ok) == 0:
        print(f"\n=== {title} Metrics ===")
        print("No parse_ok samples. Cannot compute metrics.")
        return

    y_true = df_ok[label_col_true].astype(str)
    y_pred = df_ok[label_col_pred].astype(str)

    acc = accuracy_score(y_true, y_pred)
    macro = f1_score(y_true, y_pred, average="macro", zero_division=0)
    micro = f1_score(y_true, y_pred, average="micro", zero_division=0)
    weighted = f1_score(y_true, y_pred, average="weighted", zero_division=0)

    print(f"\n=== {title} Metrics (on parse_ok samples: {len(df_ok)}/{len(df_res)}) ===")
    print("Accuracy:", acc)
    print("Macro-F1:", macro)
    print("Micro-F1:", micro)
    print("Weighted-F1:", weighted)
    print("\nClassification Report:\n")
    print(classification_report(y_true, y_pred, zero_division=0))


def main():
    df = pd.read_csv(INPUT_CSV)
    n = len(df)
    print(f"Loaded {n} rows from {INPUT_CSV}")

    # resume support
    done = {}
    if OUT_CSV.exists():
        prev = pd.read_csv(OUT_CSV)
        for _, r in prev.iterrows():
            done[int(r["idx"])] = r.to_dict()
        print(f"Resuming: found {len(done)} already processed rows in {OUT_CSV}")

    haz_opts = "; ".join(HAZ_LIST)
    prod_opts = "; ".join(PROD_LIST)

    rows = []
    start_time = time.time()

    for i, r in df.iterrows():
        if int(i) in done:
            rows.append(done[int(i)])
            continue

        prompt = PROMPT_TEMPLATE.format(
            haz_opts=haz_opts,
            prod_opts=prod_opts,
            title=str(r["title"]),
            text=str(r["text"])
        )

        t0 = time.time()
        try:
            out = run_ollama(prompt)
            haz_pred, prod_pred, parse_ok, haz_ok, prod_ok = parse_two_lines(out)
            err = ""
        except Exception as e:
            out = ""
            haz_pred, prod_pred, parse_ok, haz_ok, prod_ok = None, None, False, False, False
            err = str(e)

        dt = time.time() - t0

        row = {
            "idx": int(i),
            "parse_ok": bool(parse_ok),
            "haz_pred": haz_pred,
            "prod_pred": prod_pred,
            "haz_in_list": bool(haz_ok),
            "prod_in_list": bool(prod_ok),
            "haz_true": r.get("hazard-category"),
            "prod_true": r.get("product-category"),
            "latency_sec": round(dt, 3),
            "error": err,
            "raw_output": out[:1500]
        }
        rows.append(row)

        if (i + 1) % 10 == 0:
            elapsed = time.time() - start_time
            print(f"[{i+1}/{n}] parse_ok={parse_ok} haz={haz_pred} prod={prod_pred} (elapsed {elapsed/60:.1f} min)")

        if (i + 1) % SAVE_EVERY == 0:
            pd.DataFrame(rows).to_csv(OUT_CSV, index=False)

    out_df = pd.DataFrame(rows)
    out_df.to_csv(OUT_CSV, index=False)
    print(f"\nSaved final: {OUT_CSV}")

    print("\nParse OK rate:", out_df["parse_ok"].mean())
    print("Hazard in-list rate:", out_df["haz_in_list"].mean())
    print("Product in-list rate:", out_df["prod_in_list"].mean())
    print("Avg latency (sec):", out_df["latency_sec"].mean())

    compute_metrics(out_df, "haz_true", "haz_pred", "Hazard-category")
    compute_metrics(out_df, "prod_true", "prod_pred", "Product-category")


if __name__ == "__main__":
    main()
# Out:
# Loaded 565 rows from incidents_valid.csv
# [10/565] parse_ok=True haz=biological prod=meat, egg and dairy products (elapsed 0.1 min)
# [20/565] parse_ok=True haz=biological prod=non-alcoholic beverages (elapsed 0.2 min)
# [30/565] parse_ok=True haz=allergens prod=cereals and bakery products (elapsed 0.3 min)
# [40/565] parse_ok=True haz=allergens prod=meat, egg and dairy products (elapsed 0.4 min)
# [50/565] parse_ok=True haz=foreign bodies prod=fruits and vegetables (elapsed 0.5 min)
# [60/565] parse_ok=True haz=foreign bodies prod=prepared dishes and snacks (elapsed 0.6 min)
# [70/565] parse_ok=True haz=foreign bodies prod=prepared dishes and snacks (elapsed 0.7 min)
# [80/565] parse_ok=True haz=foreign bodies prod=confectionery (elapsed 0.8 min)
# [90/565] parse_ok=True haz=biological prod=prepared dishes and snacks (elapsed 0.9 min)
# [100/565] parse_ok=True haz=allergens prod=prepared dishes and snacks (elapsed 1.0 min)
# [110/565] parse_ok=True haz=allergens prod=prepared dishes and snacks (elapsed 1.1 min)
# [120/565] parse_ok=True haz=biological prod=meat, egg and dairy products (elapsed 1.2 min)
# [130/565] parse_ok=True haz=foreign bodies prod=prepared dishes and snacks (elapsed 1.3 min)
# [140/565] parse_ok=True haz=allergens prod=prepared dishes and snacks (elapsed 1.4 min)
# [150/565] parse_ok=True haz=biological prod=prepared dishes and snacks (elapsed 1.5 min)
# [160/565] parse_ok=False haz=chemical prod=None (elapsed 1.6 min)
# [170/565] parse_ok=True haz=biological prod=prepared dishes and snacks (elapsed 1.7 min)
# [180/565] parse_ok=True haz=organoleptic aspects prod=prepared dishes and snacks (elapsed 1.8 min)
# [190/565] parse_ok=True haz=biological prod=meat, egg and dairy products (elapsed 2.0 min)
# [200/565] parse_ok=True haz=allergens prod=prepared dishes and snacks (elapsed 2.1 min)
# [210/565] parse_ok=True haz=biological prod=fruits and vegetables (elapsed 2.2 min)
# [220/565] parse_ok=True haz=biological prod=meat, egg and dairy products (elapsed 2.3 min)
# [230/565] parse_ok=True haz=biological prod=cereals and bakery products (elapsed 2.4 min)
# [240/565] parse_ok=True haz=allergens prod=prepared dishes and snacks (elapsed 2.5 min)
# [250/565] parse_ok=True haz=biological prod=meat, egg and dairy products (elapsed 2.6 min)
# [260/565] parse_ok=True haz=biological prod=prepared dishes and snacks (elapsed 2.8 min)
# [270/565] parse_ok=True haz=foreign bodies prod=prepared dishes and snacks (elapsed 2.9 min)
# [280/565] parse_ok=True haz=foreign bodies prod=prepared dishes and snacks (elapsed 3.0 min)
# [290/565] parse_ok=True haz=biological prod=prepared dishes and snacks (elapsed 3.1 min)
# [300/565] parse_ok=True haz=fraud prod=prepared dishes and snacks (elapsed 3.2 min)
# [310/565] parse_ok=True haz=chemical prod=prepared dishes and snacks (elapsed 3.3 min)
# [320/565] parse_ok=True haz=foreign bodies prod=fats and oils (elapsed 3.4 min)
# [330/565] parse_ok=True haz=allergens prod=prepared dishes and snacks (elapsed 3.5 min)
# [340/565] parse_ok=True haz=foreign bodies prod=prepared dishes and snacks (elapsed 3.6 min)
# [350/565] parse_ok=True haz=allergens prod=prepared dishes and snacks (elapsed 3.7 min)
# [360/565] parse_ok=True haz=foreign bodies prod=cereals and bakery products (elapsed 3.8 min)
# [370/565] parse_ok=True haz=biological prod=meat, egg and dairy products (elapsed 3.9 min)
# [380/565] parse_ok=True haz=allergens prod=prepared dishes and snacks (elapsed 4.0 min)
# [390/565] parse_ok=True haz=allergens prod=prepared dishes and snacks (elapsed 4.1 min)
# [400/565] parse_ok=False haz=biological prod=None (elapsed 4.2 min)
# [410/565] parse_ok=True haz=allergens prod=confectionery (elapsed 4.4 min)
# [420/565] parse_ok=True haz=biological prod=prepared dishes and snacks (elapsed 4.5 min)
# [430/565] parse_ok=True haz=allergens prod=non-alcoholic beverages (elapsed 4.6 min)
# [440/565] parse_ok=True haz=allergens prod=other food product / mixed (elapsed 4.7 min)
# [450/565] parse_ok=True haz=allergens prod=ices and desserts (elapsed 4.8 min)
# [460/565] parse_ok=True haz=allergens prod=prepared dishes and snacks (elapsed 4.9 min)
# [470/565] parse_ok=True haz=biological prod=alcoholic beverages (elapsed 5.0 min)
# [480/565] parse_ok=True haz=allergens prod=prepared dishes and snacks (elapsed 5.1 min)
# [490/565] parse_ok=True haz=chemical prod=non-alcoholic beverages (elapsed 5.2 min)
# [500/565] parse_ok=True haz=allergens prod=confectionery (elapsed 5.3 min)
# [510/565] parse_ok=True haz=biological prod=prepared dishes and snacks (elapsed 5.4 min)
# [520/565] parse_ok=True haz=other hazard prod=prepared dishes and snacks (elapsed 5.5 min)
# [530/565] parse_ok=True haz=allergens prod=confectionery (elapsed 5.6 min)
# [540/565] parse_ok=True haz=biological prod=meat, egg and dairy products (elapsed 5.7 min)
# [550/565] parse_ok=True haz=allergens prod=meat, egg and dairy products (elapsed 5.8 min)
# [560/565] parse_ok=True haz=chemical prod=prepared dishes and snacks (elapsed 5.9 min)
#
# Saved final: results\zero_shot_valid_grounded_canon.csv
#
# Parse OK rate: 0.9929203539823008
# Hazard in-list rate: 1.0
# Product in-list rate: 0.9929203539823008
# Avg latency (sec): 0.6353256637168143
#
# === Hazard-category Metrics (on parse_ok samples: 561/565) ===
# Accuracy: 0.8770053475935828
# Macro-F1: 0.5744872807543386
# Micro-F1: 0.8770053475935828
# Weighted-F1: 0.8591233153081879
#
# Classification Report:
#
#                                 precision    recall  f1-score   support
#
#                      allergens       0.94      0.98      0.96       206
#                     biological       0.88      0.99      0.94       192
#                       chemical       0.81      0.75      0.78        28
# food additives and flavourings       0.00      0.00      0.00         2
#                 foreign bodies       0.97      0.95      0.96        63
#                          fraud       0.86      0.15      0.25        41
#           organoleptic aspects       0.60      0.38      0.46         8
#                   other hazard       0.32      0.43      0.36        14
#               packaging defect       0.50      0.43      0.46         7
#
#                       accuracy                           0.88       561
#                      macro avg       0.65      0.56      0.57       561
#                   weighted avg       0.88      0.88      0.86       561
#
#
# === Product-category Metrics (on parse_ok samples: 561/565) ===
# Accuracy: 0.40641711229946526
# Macro-F1: 0.39210992102333825
# Micro-F1: 0.40641711229946526
# Weighted-F1: 0.4089943839917889
#
# Classification Report:
#
#                                                    precision    recall  f1-score   support
#
#                               alcoholic beverages       0.75      0.43      0.55         7
#                       cereals and bakery products       0.67      0.19      0.29        75
#      cocoa and cocoa preparations, coffee and tea       0.00      0.00      0.00        15
#                                     confectionery       0.28      0.42      0.34        26
# dietetic foods, food supplements, fortified foods       0.62      0.38      0.48        13
#                                     fats and oils       0.60      0.75      0.67         4
#                                    feed materials       1.00      1.00      1.00         1
#                    food additives and flavourings       0.00      0.00      0.00         0
#                             fruits and vegetables       0.94      0.33      0.49        51
#                                  herbs and spices       1.00      0.12      0.21        17
#                                 ices and desserts       1.00      0.08      0.15        24
#                      meat, egg and dairy products       0.80      0.64      0.71       146
#                           non-alcoholic beverages       0.68      0.68      0.68        19
#                      nuts, nut products and seeds       0.91      0.30      0.45        33
#                        other food product / mixed       0.00      0.00      0.00        10
#                                          pet feed       1.00      1.00      1.00         1
#                        prepared dishes and snacks       0.17      0.89      0.29        56
#                                           seafood       1.00      0.07      0.14        27
#              soups, broths, sauces and condiments       0.00      0.00      0.00        36
#
#                                          accuracy                           0.41       561
#                                         macro avg       0.60      0.38      0.39       561
#                                      weighted avg       0.64      0.41      0.41       561
